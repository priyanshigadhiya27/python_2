# %%
import requests,json

# %%
API_key='e169320373a0100a2ebba92143523e6d'
city_name='Ahmedabad'
url=f"http://api.openweathermap.org/geo/1.0/direct?q={city_name}&appid={API_key}"

response=requests.get(url)
# response.status_code
result=response.json()
lat=result[0]['lat']
lon=result[0]['lon']

# %%
lat,lon

# %%
url=f"http://api.openweathermap.org/data/2.5/air_pollution?lat={lat}&lon={lon}&appid={API_key}"
response=requests.get(url)
result=response.json()
print(result['list'][0]['main']['aqi'],"aqi")
print(result['list'][0]['components']['co'],"co")
print(result['list'][0]['components']['no'],"no")
print(result['list'][0]['components']['no2'],"no2")
print(result['list'][0]['components']['o3'],"o3")
print(result['list'][0]['components']['so2'],"so2")
print(result['list'][0]['components']['pm2_5'],"pm2_5")
print(result['list'][0]['components']['pm10'],"pm10")
print(result['list'][0]['components']['nh3'],"nh3")

print(json.dumps(result,indent=5))

# %%
d={'aqi':[],'co':[],'no':[],'no2':[],'o3':[],'so2':[],'pm2_5':[],'pm10':[],'nh3':[]}

url=f"http://api.openweathermap.org/data/2.5/air_pollution/forecast?lat={lat}&lon={lon}&appid={API_key}"
response=requests.get(url)
result=response.json()
print(json.dumps(result,indent=5))
len(result['list'])
for i in result['list']:
    d['aqi'].append(i['main']['aqi'])
    d['co'].append(i['components']['co'])
    d['o3'].append(i['components']['o3'])
    d['no'].append(i['components']['no'])
    d['no2'].append(i['components']['no2'])
    d['so2'].append(i['components']['so2'])
    d['pm2_5'].append(i['components']['pm2_5'])
    d['pm10'].append(i['components']['pm10'])
    d['nh3'].append(i['components']['nh3'])
import pandas as pd
df=pd.DataFrame(d)
df.head()

# %%
# temp,temp_min,temp_max,pressure,description,humidity,wind_speed,clouds_all,visibilty

# %%
url=f"https://api.openweathermap.org/data/2.5/weather?lat={lat}&lon={lon}&appid={API_key}"
response=requests.get(url)
result=response.json()
print(json.dumps(result,indent=5))
print("temp",result['main']['temp'])
print("temp_min",result['main']['temp_min'])
print("temp_max",result['main']['temp_max'])
print("pressure",result['main']['pressure'])
print("description",result['main']['description'])
print("humidity",result['main']['humidity'])
print("wind_speed",result['main']['wind_speed'])
print("clouds_all",result['main']['clouds_all'])
print("visibility",result['main']['visibility'])
# Out:
# {
#      "coord": {
#           "lon": 72.5801,
#           "lat": 23.0215
#      },
#      "weather": [
#           {
#                "id": 800,
#                "main": "Clear",
#                "description": "clear sky",
#                "icon": "01d"
#           }
#      ],
#      "base": "stations",
#      "main": {
#           "temp": 312.25,
#           "feels_like": 315.82,
#           "temp_min": 312.25,
#           "temp_max": 312.25,
#           "pressure": 1004,
#           "humidity": 33,
#           "sea_level": 1004,
#           "grnd_level": 999
#      },
#      "visibility": 10000,
#      "wind": {
#           "speed": 1.59,
#           "deg": 249,
#           "gust": 1.43
#      },
#      "clouds": {
#           "all": 0
#      },
#      "dt": 1780471606,
#      "sys": {
#           "country": "IN",
#           "sunrise": 1780446232,
#           "sunset": 1780494720
#      },
#      "timezone": 19800,
#      "id": 1279233,
#      "name": "Ahmedabad",
# ...
