# %%
import pandas as pd
import numpy as np
ds=pd.Series([10,20,30,40],index=['V','H','A','B'],dtype='float',name='priyanshi')
print(ds)
# Out:
# V    10.0
# H    20.0
# A    30.0
# B    40.0
# Name: priyanshi, dtype: float64

# %%
import pandas as pd
import numpy as np
ds=pd.Series((10,20,30,40),index=['V','H','A','B'],dtype='float',name='priyanshi')
print(ds)
# Out:
# V    10.0
# H    20.0
# A    30.0
# B    40.0
# Name: priyanshi, dtype: float64

# %%
import pandas as pd
import numpy as np
ds=pd.Series({'A':20,'B':30},dtype='float',name='priyanshi')
print(ds)
# Out:
# A    20.0
# B    30.0
# Name: priyanshi, dtype: float64

# %%
import pandas as pd
import numpy as np
ds=pd.Series(np.array([10,20,30,40]),index=['V','H','A','B'],dtype='float',name='priyanshi')
print(ds)
# Out:
# V    10.0
# H    20.0
# A    30.0
# B    40.0
# Name: priyanshi, dtype: float64

# %%
import pandas as pd
import numpy as np
ds1=pd.DataFrame([['A','B','C'],[10,20,30],[1,2,3]],index=['p','q','r'],columns=['A','B','C'])
print(ds1)
# Out:
#     A   B   C
# p   A   B   C
# q  10  20  30
# r   1   2   3

# %%
import pandas as pd
import numpy as np
ds=pd.DataFrame((10,20,30,40),index=['V','H','A','B'],dtype='float')
print(ds)
# Out:
#       0
# V  10.0
# H  20.0
# A  30.0
# B  40.0

# %%
import pandas as pd
import numpy as np
ds=pd.DataFrame({'name':['A','B','C'],'marks':[10,20,30]},index=['P','Q','R'])
print(ds)
# Out:
#   name  marks
# P    A     10
# Q    B     20
# R    C     30

# %%
import pandas as pd
import numpy as np
ds=pd.DataFrame([{'name':'abc','mark':30}])
print(ds)
# Out:
#   name  mark
# 0  abc    30

# %%
df=pd.read_csv('train.csv')
df.index
df.columns
df.size
df.shape
df.values
df.dtypes
df.ndim
df.T
df.set_index('Name')
df=df.set_index('Name')
# Out:
#                                                   Name  PassengerId  Survived  \
# 0                              Braund, Mr. Owen Harris            1         0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...            2         1
# 2                               Heikkinen, Miss. Laina            3         1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)            4         1
# 4                             Allen, Mr. William Henry            5         0
# ..                                                 ...          ...       ...
# 886                              Montvila, Rev. Juozas          887         0
# 887                       Graham, Miss. Margaret Edith          888         1
# 888           Johnston, Miss. Catherine Helen "Carrie"          889         0
# 889                              Behr, Mr. Karl Howell          890         1
# 890                                Dooley, Mr. Patrick          891         0
#
# ...

# %%
df=df.reset_index()
df
# Out:
#      index                                               Name  PassengerId  \
# 0        0                            Braund, Mr. Owen Harris            1
# 1        1  Cumings, Mrs. John Bradley (Florence Briggs Th...            2
# 2        2                             Heikkinen, Miss. Laina            3
# 3        3       Futrelle, Mrs. Jacques Heath (Lily May Peel)            4
# 4        4                           Allen, Mr. William Henry            5
# ..     ...                                                ...          ...
# 886    886                              Montvila, Rev. Juozas          887
# 887    887                       Graham, Miss. Margaret Edith          888
# 888    888           Johnston, Miss. Catherine Helen "Carrie"          889
# 889    889                              Behr, Mr. Karl Howell          890
# 890    890                                Dooley, Mr. Patrick          891
#
# ...

# %%
df1=pd.DataFrame({'name':['A','B','C'],'marks':[10,20,30],'CGPA':[1,2,3]},index=['P','Q','R'])
print(df1)
# Out:
#   name  marks  CGPA
# P    A     10     1
# Q    B     20     2
# R    C     30     3

# %%
df1=df1.set_index('name',drop=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-76-6b711d47a647> in <module>
# ----> 1 df1=df1.set_index('name',drop=True)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['name'] are in the columns"

# %%
df1=df1.set_index('name',drop=False)
df1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-75-25c2a42410a2> in <module>
# ----> 1 df1=df1.set_index('name',drop=False)
#       2 df1
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['name'] are in the columns"

# %%
print(df1)
# Out:
#       marks  CGPA
# name
# A        10     1
# B        20     2
# C        30     3

# %%
df1=df1.reset_index()
df1
# Out:
#   name  marks  CGPA
# 0    A     10     1
# 1    B     20     2
# 2    C     30     3

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[['Name','Age']]
# Out:
#                                                   Name   Age
# 0                              Braund, Mr. Owen Harris  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0
# 2                               Heikkinen, Miss. Laina  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0
# 4                             Allen, Mr. William Henry  35.0
# ..                                                 ...   ...
# 886                              Montvila, Rev. Juozas  27.0
# 887                       Graham, Miss. Margaret Edith  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN
# 889                              Behr, Mr. Karl Howell  26.0
# 890                                Dooley, Mr. Patrick  32.0
#
# [891 rows x 2 columns]

# %%
df.iloc[2:3,:]
# Out:
#    PassengerId  Survived  Pclass                    Name     Sex   Age  SibSp  \
# 2            3         1       3  Heikkinen, Miss. Laina  female  26.0      0
#
#    Parch            Ticket   Fare Cabin Embarked
# 2      0  STON/O2. 3101282  7.925   NaN        S

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.iloc[1:0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.iloc[1:10,2:5]
# Out:
#    Pclass                                               Name     Sex
# 1       1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2       3                             Heikkinen, Miss. Laina  female
# 3       1       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4       3                           Allen, Mr. William Henry    male
# 5       3                                   Moran, Mr. James    male
# 6       1                            McCarthy, Mr. Timothy J    male
# 7       3                     Palsson, Master. Gosta Leonard    male
# 8       3  Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female
# 9       2                Nasser, Mrs. Nicholas (Adele Achem)  female

# %%
df=df.set_index('Name')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-105-9d6b9c8672eb> in <module>
# ----> 1 df=df.set_index('Name')
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4549
#    4550         if missing:
# -> 4551             raise KeyError(f"None of {missing} are in the columns")
#    4552
#    4553         if inplace:
#
# KeyError: "None of ['Name'] are in the columns"

# %%
df
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# ...                                                         ...       ...
# Montvila, Rev. Juozas                                       887         0
# Graham, Miss. Margaret Edith                                888         1
# Johnston, Miss. Catherine Helen "Carrie"                    889         0
# Behr, Mr. Karl Howell                                       890         1
# Dooley, Mr. Patrick                                         891         0
#
# ...

# %%
df.loc['Cumings, Mrs. John Bradley (Florence Briggs Thayer)']
# Out:
# PassengerId           2
# Survived              1
# Pclass                1
# Sex              female
# Age                  38
# SibSp                 1
# Parch                 0
# Ticket         PC 17599
# Fare            71.2833
# Cabin               C85
# Embarked              C
# Name: Cumings, Mrs. John Bradley (Florence Briggs Thayer), dtype: object

# %%
df.loc['Futrelle, Mrs. Jacques Heath (Lily May Peel)','PassengerId':'Age']
# Out:
# PassengerId         4
# Survived            1
# Pclass              1
# Sex            female
# Age                35
# Name: Futrelle, Mrs. Jacques Heath (Lily May Peel), dtype: object

# %%
import pandas as pd
import numpy as np
ds1=pd.DataFrame([[10,40,70],[20,50,80],[30,60,90]],index=['A','B','C'],columns=['P','Q','R'])
print(ds1)
# Out:
#     P   Q   R
# A  10  40  70
# B  20  50  80
# C  30  60  90

# %%
ds1.loc['B','Q']
# Out:
# 50

# %%
ds1.loc['B']
# Out:
# P    20
# Q    50
# R    80
# Name: B, dtype: int64

# %%
ds1.loc[:,'R']
# Out:
# A    70
# B    80
# C    90
# Name: R, dtype: int64

# %%
ds1.loc['B','Q']=100
ds1
# Out:
#     P    Q   R
# A  10   40  70
# B  20  100  80
# C  30   60  90

# %%
ds1['D']=7
ds1
# Out:
#     P    Q   R  D
# A  10   40  70  7
# B  20  100  80  7
# C  30   60  90  7

# %%
ds1['D']=ds1['P']//ds1['Q']

# %%
ds1
# Out:
#     P    Q   R  D
# A  10   40  70  0
# B  20  100  80  0
# C  30   60  90  0

# %%
ds1.loc['A':'C','P':'R']=7
ds1
# Out:
#    P  Q  R  D
# A  7  7  7  0
# B  7  7  7  0
# C  7  7  7  0

# %%
import pandas as pd
import numpy as np

df=pd.DataFrame(np.random.randint(1,100,(8,5)),columns=['A','B','C','D','E'])
print(df)
# Out:
#     A   B   C   D   E
# 0  65  33  36  47  77
# 1  61  73  58  37  40
# 2  61  23  87  67  22
# 3  43  94   5  90  51
# 4  83  85  33  27   6
# 5   4  21  29  32  62
# 6  34  49  40  35  61
# 7  77  96  57  83  76

# %%
df.shape
# Out:
# (8, 5)

# %%
df.size
# Out:
# 40

# %%
df.ndim
# Out:
# 2

# %%
df['sum']=df['A']+df['B']+df['C']+df['D']+df['E']
df
# Out:
#     A   B   C   D   E  sum
# 0  65  33  36  47  77  258
# 1  61  73  58  37  40  269
# 2  61  23  87  67  22  260
# 3  43  94   5  90  51  283
# 4  83  85  33  27   6  234
# 5   4  21  29  32  62  148
# 6  34  49  40  35  61  219
# 7  77  96  57  83  76  389

# %%
df.iloc=[5,2]=60
# Out:
#   File "<ipython-input-15-6d1a0fd5f81f>", line 1
#     df.iloc=[5,2]=60
#             ^
# SyntaxError: cannot assign to literal

# %%
df
# Out:
#     A   B   C   D   E  sum
# 0  65  33  36  47  77  258
# 1  61  73  58  37  40  269
# 2  61  23  87  67  22  260
# 3  43  94   5  90  51  283
# 4  83  85  33  27   6  234
# 5   4  21  29  32  62  148
# 6  34  49  40  35  61  219
# 7  77  96  57  83  76  389

# %%
df.loc[2:7,'B':'D']
# Out:
#     B   C   D
# 2  23  87  67
# 3  94   5  90
# 4  85  33  27
# 5  21  29  32
# 6  49  40  35
# 7  96  57  83

# %%
df.loc[10]=[70,30,50,40,50,68]
df
# Out:
#      A   B   C   D   E  sum
# 0   65  33  36  47  77  258
# 1   61  73  58  37  40  269
# 2   61  23  87  67  22  260
# 3   43  94   5  90  51  283
# 4   83  85  33  27   6  234
# 5    4  21  29  32  62  148
# 6   34  49  40  35  61  219
# 7   77  96  57  83  76  389
# 10  70  30  50  40  50   68

# %%
import pandas as pd
import numpy as np

df1=pd.DataFrame({'CourseId':['c1','c2','c3','c4','c5'],'CouseName':['A','B','C','D','E'],'Credits':[]})
print(df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-98d7bd9c59a5> in <module>
#       2 import numpy as np
#       3
# ----> 4 df1=pd.DataFrame(columns=['CourseID','Credits','Faculty'],Credits=['c1','c2','c3','c4','c5'])
#       5 print(df)
#
# TypeError: __init__() got an unexpected keyword argument 'Credits'

# %%
df=pd.read_csv('train.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
# 7            8         0       3
# 8            9         1       3
# 9           10         1       2
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# ...

# %%
df.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
df.sample(4)
# Out:
#      PassengerId  Survived  Pclass  \
# 382          383         0       3
# 295          296         0       1
# 862          863         1       1
# 753          754         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 382                                 Tikkanen, Mr. Juho    male  32.0      0
# 295                                  Lewy, Mr. Ervin G    male   NaN      0
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 753                                 Jonkoff, Mr. Lalio    male  23.0      0
#
#      Parch             Ticket     Fare Cabin Embarked
# 382      0  STON/O 2. 3101293   7.9250   NaN        S
# 295      0           PC 17612  27.7208   NaN        C
# 862      0              17466  25.9292   D17        S
# 753      0             349204   7.8958   NaN        S

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                    Name   Sex  \
# count    891.000000  891.000000  891.000000                     891   891
# unique          NaN         NaN         NaN                     891     2
# top             NaN         NaN         NaN  Sutehall, Mr. Henry Jr  male
# freq            NaN         NaN         NaN                       1   577
# mean     446.000000    0.383838    2.308642                     NaN   NaN
# std      257.353842    0.486592    0.836071                     NaN   NaN
# min        1.000000    0.000000    1.000000                     NaN   NaN
# 25%      223.500000    0.000000    2.000000                     NaN   NaN
# 50%      446.000000    0.000000    3.000000                     NaN   NaN
# 75%      668.500000    1.000000    3.000000                     NaN   NaN
# max      891.000000    1.000000    3.000000                     NaN   NaN
#
#                Age       SibSp       Parch Ticket        Fare Cabin Embarked
# ...

# %%
df.describe(include='object')
# Out:
#                           Name   Sex Ticket Cabin Embarked
# count                      891   891    891   204      889
# unique                     891     2    681   147        3
# top     Sutehall, Mr. Henry Jr  male   1601    G6        S
# freq                         1   577      7     4      644

# %%
df.describe(exclude='integer')
# Out:
#                           Name   Sex         Age Ticket        Fare Cabin  \
# count                      891   891  714.000000    891  891.000000   204
# unique                     891     2         NaN    681         NaN   147
# top     Sutehall, Mr. Henry Jr  male         NaN   1601         NaN    G6
# freq                         1   577         NaN      7         NaN     4
# mean                       NaN   NaN   29.699118    NaN   32.204208   NaN
# std                        NaN   NaN   14.526497    NaN   49.693429   NaN
# min                        NaN   NaN    0.420000    NaN    0.000000   NaN
# 25%                        NaN   NaN   20.125000    NaN    7.910400   NaN
# 50%                        NaN   NaN   28.000000    NaN   14.454200   NaN
# 75%                        NaN   NaN   38.000000    NaN   31.000000   NaN
# max                        NaN   NaN   80.000000    NaN  512.329200   NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# ...

# %%
df.describe(percentiles=[0.2,0.3,0.5])
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 20%     179.000000    0.000000    1.000000   19.000000    0.000000
# 30%     268.000000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 20%      0.000000    7.854200
# 30%      0.000000    8.050000
# 50%      0.000000   14.454200
# max      6.000000  512.329200

# %%
df.nunique()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-42-56fd298f3a6b> in <module>
# ----> 1 df.nunique(dtypes=8)
#
# TypeError: nunique() got an unexpected keyword argument 'dtypes'

# %%
df.Sex.unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df.Age.unique()
# Out:
# array([22.  , 38.  , 26.  , 35.  ,   nan, 54.  ,  2.  , 27.  , 14.  ,
#         4.  , 58.  , 20.  , 39.  , 55.  , 31.  , 34.  , 15.  , 28.  ,
#         8.  , 19.  , 40.  , 66.  , 42.  , 21.  , 18.  ,  3.  ,  7.  ,
#        49.  , 29.  , 65.  , 28.5 ,  5.  , 11.  , 45.  , 17.  , 32.  ,
#        16.  , 25.  ,  0.83, 30.  , 33.  , 23.  , 24.  , 46.  , 59.  ,
#        71.  , 37.  , 47.  , 14.5 , 70.5 , 32.5 , 12.  ,  9.  , 36.5 ,
#        51.  , 55.5 , 40.5 , 44.  ,  1.  , 61.  , 56.  , 50.  , 36.  ,
#        45.5 , 20.5 , 62.  , 41.  , 52.  , 63.  , 23.5 ,  0.92, 43.  ,
#        60.  , 10.  , 64.  , 13.  , 48.  ,  0.75, 53.  , 57.  , 80.  ,
#        70.  , 24.5 ,  6.  ,  0.67, 30.5 ,  0.42, 34.5 , 74.  ])

# %%
df.Pclass.unique()
# Out:
# array([3, 1, 2], dtype=int64)

# %%
df.Sex.value_counts()
# Out:
# male      577
# female    314
# Name: Sex, dtype: int64

# %%
df.Embarked.value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
df[df["Survived"]==1].Sex.value_counts()
# Out:
# female    233
# male      109
# Name: Sex, dtype: int64

# %%
df[df["Age"]>18]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df[df["Survived"]==1].Pclass.value_counts()
# Out:
# 1    136
# 3    119
# 2     87
# Name: Pclass, dtype: int64

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data=pd.DataFrame([[1,2,3,np.nan],[4,np.nan,5,np.nan],[7,8,9,10],[1,np.nan,3,4]],columns=["A","B","C","D"])
data
# Out:
#    A    B  C     D
# 0  1  2.0  3   NaN
# 1  4  NaN  5   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %%
data.dropna(axis=0,how="any",subset=["D","B"])  #d or b
# Out:
#    A    B  C     D
# 2  7  8.0  9  10.0

# %%
data.dropna(axis=0,how="all",subset=["D","B"])  # d and b
# Out:
#    A    B  C     D
# 0  1  2.0  3   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %%
data.dropna(thresh=2)
# Out:
#    A    B  C     D
# 0  1  2.0  3   NaN
# 1  4  NaN  5   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %%
df.dropna(subset=['Cabin'])
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dropna()
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#    A    B  C     D
# 0  1  2.0  3   NaN
# 1  4  NaN  5   NaN
# 2  7  8.0  9  10.0
# 3  1  NaN  3   4.0

# %%
data.fillna(data.mean())
# Out:
#    A    B  C     D
# 0  1  2.0  3   7.0
# 1  4  5.0  5   7.0
# 2  7  8.0  9  10.0
# 3  1  5.0  3   4.0

# %%
data['B']=data['B'].fillna(data['B'].mean())
data
# Out:
#    A    B  C     D
# 0  1  2.0  3   NaN
# 1  4  5.0  5   NaN
# 2  7  8.0  9  10.0
# 3  1  5.0  3   4.0

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df["Age"]=df["Age"].fillna(df.Age.mean())
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
df.Age.mean()
# Out:
# 29.699117647058763

# %%
df.Embarked.mode()
# Out:
# 0    S
# dtype: object

# %%
df["Embarked"]=df["Embarked"].fillna(df.Embarked.mode()[0])
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex        Age  \
# 0                              Braund, Mr. Owen Harris    male  22.000000
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 4                             Allen, Mr. William Henry    male  35.000000
# ..                                                 ...     ...        ...
# ...

# %%
data.drop('D',axis=1)
# Out:
#    A    B  C
# 0  1  2.0  3
# 1  4  5.0  5
# 2  7  8.0  9
# 3  1  5.0  3

# %%
df[df["Sex"]!="female"]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 0              1         0       3         Braund, Mr. Owen Harris  male
# 4              5         0       3        Allen, Mr. William Henry  male
# 5              6         0       3                Moran, Mr. James  male
# 6              7         0       1         McCarthy, Mr. Timothy J  male
# 7              8         0       3  Palsson, Master. Gosta Leonard  male
# ..           ...       ...     ...                             ...   ...
# 883          884         0       2   Banfield, Mr. Frederick James  male
# 884          885         0       3          Sutehall, Mr. Henry Jr  male
# 886          887         0       2           Montvila, Rev. Juozas  male
# 889          890         1       1           Behr, Mr. Karl Howell  male
# 890          891         0       3             Dooley, Mr. Patrick  male
#
#            Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# ...

# %%
i=df[df["Sex"]!="female"].index

# %%
df.drop(i)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 8              9         1       3
# 9             10         1       2
# ..           ...       ...     ...
# 880          881         1       2
# 882          883         0       3
# 885          886         0       3
# 887          888         1       1
# 888          889         0       3
#
#                                                   Name     Sex        Age  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.000000
# 2                               Heikkinen, Miss. Laina  female  26.000000
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.000000
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.000000
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.000000
# ..                                                 ...     ...        ...
# ...

# %%
ds=pd.DataFrame([[1,1,2,3],[2,1,1,3],[1,1,2,3],[2,1,1,3],[1,1,2,2]],index=[7,8,9,10,11],columns=["p","q","r","s"])

# %%
ds
# Out:
#     p  q  r  s
# 7   1  1  2  3
# 8   2  1  1  3
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %%
ds.duplicated(subset=["p"])
# Out:
# 7     False
# 8     False
# 9      True
# 10     True
# 11     True
# dtype: bool

# %%
ds.duplicated().sum()
# Out:
# 2

# %%
ds.drop_duplicates(keep='last')
# Out:
#     p  q  r  s
# 9   1  1  2  3
# 10  2  1  1  3
# 11  1  1  2  2

# %%
ds.drop_duplicates(subset=["q"])
# Out:
#    p  q  r  s
# 7  1  1  2  3
